# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2

# %%
print('TensorFlow Version : ', tf.__version__)
# Out:
# TensorFlow Version :  2.17.1

# %%
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
# Out:
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'

# %%
# !ls "/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test"
# Out:
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Train dataset creation
## Images resized to 180 x 180 as per the problem statement

train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                               seed=123,
                                                               validation_split = 0.2,
                                                               subset = 'training',
                                                               image_size=(img_height, img_width),
                                                               batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Validation dataset creation
## Images resized to 180 x 180 as per the problem statement
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                               seed=123,
                                                               validation_split = 0.2,
                                                               subset = 'validation',
                                                               image_size=(img_height, img_width),
                                                               batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
# Number of target labels are 9
target_labels = 9

# Creating initial model with 3 (Convolutional + MaxPooling) layers followed by a dense hidden layer and output layer
# padding = 'same' given so that output shape remains same after convolution
model = Sequential([
#  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(target_labels, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 61952)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      15,859,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,955,529 (60.87 MB)
#  Trainable params: 15,955,529 (60.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
# %%time
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 189s 720ms/step - accuracy: 0.2704 - loss: 2.3294 - val_accuracy: 0.3445 - val_loss: 1.7527
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4312 - loss: 1.6034 - val_accuracy: 0.5011 - val_loss: 1.4373
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4850 - loss: 1.4366 - val_accuracy: 0.5235 - val_loss: 1.3768
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5650 - loss: 1.2869 - val_accuracy: 0.4899 - val_loss: 1.4278
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5664 - loss: 1.2109 - val_accuracy: 0.5145 - val_loss: 1.4649
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6004 - loss: 1.1460 - val_accuracy: 0.5168 - val_loss: 1.4639
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6300 - loss: 1.0171 - val_accuracy: 0.5257 - val_loss: 1.5846
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6831 - loss: 0.9301 - val_accuracy: 0.5503 - val_loss: 1.4454
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6829 - loss: 0.9149 - val_accuracy: 0.5436 - val_loss: 1.4253
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7168 - loss: 0.7648 - val_accuracy: 0.5145 - val_loss: 1.6815
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7603 - loss: 0.6279 - val_accuracy: 0.5884 - val_loss: 1.5260
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7949 - loss: 0.5497 - val_accuracy: 0.5257 - val_loss: 1.8475
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8080 - loss: 0.5426 - val_accuracy: 0.5101 - val_loss: 1.7945
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8072 - loss: 0.5477 - val_accuracy: 0.5123 - val_loss: 2.0621
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8337 - loss: 0.4473 - val_accuracy: 0.5145 - val_loss: 1.9375
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8528 - loss: 0.4037 - val_accuracy: 0.5011 - val_loss: 2.2340
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8348 - loss: 0.4341 - val_accuracy: 0.5257 - val_loss: 2.3760
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8674 - loss: 0.3437 - val_accuracy: 0.5145 - val_loss: 2.0641
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8874 - loss: 0.2934 - val_accuracy: 0.4966 - val_loss: 2.4016
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9005 - loss: 0.2510 - val_accuracy: 0.5324 - val_loss: 2.2158
# CPU times: user 59.3 s, sys: 2.33 s, total: 1min 1s
# Wall time: 3min 44s

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
#
# ### Observations
# 1. The model's validation accuracy remains consistently around 50%.
#
# 2. A high training accuracy along with low validation accuracy definitely suggests overfitting as the model seems to have memorized the patterns in the training data. Model is not able to generalize the learning to the validation set.
#
# 3. To address this issue, augmentation techniques will be employed. Given the limited training data available, new samples will be generated by making slight modifications to existing data (such as horizontal/vertical image flipping, minor image rotations, etc.), which will then be used for training the model.
#
# 4. We should also use dropouts to reduce model complexity and overfitting.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here
augmentation_data = keras.Sequential([
                                      layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.RandomRotation(0.1),
                                      layers.RandomZoom(0.1),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    augmented_image = augmentation_data(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_image[0].numpy().astype("uint8"))
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
#model = Sequential([
#  augmentation_data,
#  layers.Rescaling(1./255),
#  layers.Conv2D(16, (3, 3), padding='same', activation='relu'),
#  layers.MaxPooling2D(),
#  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
#  layers.MaxPooling2D(),
#  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
#  layers.MaxPooling2D(),
#  layers.Dropout(0.2),
#  layers.Flatten(),
#  layers.Dense(128, activation='relu'),
#  layers.Dense(target_labels)
#])
model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(target_labels, activation='softmax')
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 45, 45, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 61952)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │      15,859,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,955,529 (60.87 MB)
#  Trainable params: 15,955,529 (60.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
# %%time
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.2083 - loss: 2.2913 - val_accuracy: 0.3803 - val_loss: 1.7761
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.3550 - loss: 1.7985 - val_accuracy: 0.3848 - val_loss: 1.6178
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.3922 - loss: 1.7186 - val_accuracy: 0.4698 - val_loss: 1.5299
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.3832 - loss: 1.6625 - val_accuracy: 0.5011 - val_loss: 1.4937
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.4637 - loss: 1.5553 - val_accuracy: 0.5034 - val_loss: 1.4901
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.4985 - loss: 1.4495 - val_accuracy: 0.5369 - val_loss: 1.3770
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5229 - loss: 1.3832 - val_accuracy: 0.5391 - val_loss: 1.3464
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5176 - loss: 1.3570 - val_accuracy: 0.5302 - val_loss: 1.3272
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5414 - loss: 1.3296 - val_accuracy: 0.5145 - val_loss: 1.3687
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5528 - loss: 1.3175 - val_accuracy: 0.5481 - val_loss: 1.2723
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5354 - loss: 1.2566 - val_accuracy: 0.5190 - val_loss: 1.3674
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5362 - loss: 1.3227 - val_accuracy: 0.5391 - val_loss: 1.3623
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5094 - loss: 1.3509 - val_accuracy: 0.5235 - val_loss: 1.3702
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5733 - loss: 1.2364 - val_accuracy: 0.5436 - val_loss: 1.3126
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5563 - loss: 1.2227 - val_accuracy: 0.5391 - val_loss: 1.2786
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5386 - loss: 1.2745 - val_accuracy: 0.5638 - val_loss: 1.2979
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5557 - loss: 1.2319 - val_accuracy: 0.5772 - val_loss: 1.2566
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5655 - loss: 1.2194 - val_accuracy: 0.5436 - val_loss: 1.2949
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.5847 - loss: 1.1764 - val_accuracy: 0.5369 - val_loss: 1.3852
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.5740 - loss: 1.2502 - val_accuracy: 0.5548 - val_loss: 1.3157
# CPU times: user 1min 1s, sys: 1.68 s, total: 1min 3s
# Wall time: 1min 16s

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# ### Observations
# 1. By leveraging augmented data, overfitting has been effectively addressed.
#
# 2. The training and validation accuracy of the aforementioned model fall within a similar range.
#
# 3. Both the training and validation data are showing poor performance, indicating that the model is now exhibiting underfitting.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
from glob import glob
# Find the distribution of all the classes in the training dataset and visualize it
## find the image path for all class labels (lesions)
images_path_list = [ i for i in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]

## Extract the class labels (lesions)
lesions_list = [ os.path.basename(os.path.dirname(j)) for j in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesions_list))
# Out:
# 2239

# %%
# Extract image path and class label in a dictionary
image_dict = dict(zip(images_path_list, lesions_list))
print(list(image_dict.items())[:5])

# View the image path and class label of the training set in a df
original_df = pd.DataFrame(list(image_dict.items()), columns= ['Path','Label'])
print(original_df.head())

## Inspecting the distribution of classes in the data
print(original_df[['Label']].value_counts())
# Out:
# [('/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0025606.jpg', 'vascular lesion'), ('/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026163.jpg', 'vascular lesion'), ('/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0025873.jpg', 'vascular lesion'), ('/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0024662.jpg', 'vascular lesion'), ('/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0025249.jpg', 'vascular lesion')]
#                                                 Path            Label
# 0  /content/gdrive/My Drive/Colab/CNN_assignment/...  vascular lesion
# 1  /content/gdrive/My Drive/Colab/CNN_assignment/...  vascular lesion
# 2  /content/gdrive/My Drive/Colab/CNN_assignment/...  vascular lesion
# 3  /content/gdrive/My Drive/Colab/CNN_assignment/...  vascular lesion
# 4  /content/gdrive/My Drive/Colab/CNN_assignment/...  vascular lesion
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
# @title Distribution of Skin lesion Classes

plt.figure(figsize=(10, 8))
sns.countplot(y="Label", data=original_df)
plt.title('No. of images belonging to a Type v/s Types of Skin lesions', fontsize=16)
plt.xlabel('No. of images in a particular skin lesion type', fontsize=14)
plt.ylabel('Skin Lesion Types', fontsize=14)
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# ### Observations:
#
# 1. A clear class imbalance is evident within the training data.
#
# 2. The class "seborrheic keratosis" comprises the smallest proportion of samples.
#
# 3. "Pigmented benign keratosis" and "melanoma" significantly outweigh other classes.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (11.1.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.67.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset= str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0D202A20B0>: 100%|██████████| 500/500 [00:05<00:00, 95.82 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0D601F2AD0>: 100%|██████████| 500/500 [00:05<00:00, 89.34 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0D204ADE10>: 100%|██████████| 500/500 [00:05<00:00, 89.80 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F0D20240730>: 100%|██████████| 500/500 [00:18<00:00, 27.32 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F0D20488310>: 100%|██████████| 500/500 [00:19<00:00, 26.26 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F0D203A8B80>: 100%|██████████| 500/500 [00:05<00:00, 89.02 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F0D202A0AC0>: 100%|██████████| 500/500 [00:09<00:00, 54.90 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0D43F607C0>: 100%|██████████| 500/500 [00:06<00:00, 81.42 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/
jpg',
#  '/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output/melanoma_original_ISIC_0001125.jpg_7bc64e2d-7bd0-4a02-9f04-1e65edf31c64.jpg',
#  '/content/gdrive/My Drive/Colab/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output/melanoma_original_ISIC_0001116.jpg_9a5d3a37-16d5-4b20-9324-80393471efb8.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = pd.concat([original_df, df2])
print(new_df.shape)
# Out:
# (6739, 2)

# %%
# Inspecting the classes after adding 500 samples per label
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
train_ds2 = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds2 = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
#model = Sequential([
#  augmentation_data,
#  layers.Rescaling(1./255),
#  layers.Conv2D(16, (3, 3), padding='same', activation='relu'),
#  layers.BatchNormalization(),
#  layers.MaxPooling2D(),
#  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
#  layers.BatchNormalization(),
#  layers.MaxPooling2D(),
#  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
#  layers.BatchNormalization(),
#  layers.MaxPooling2D(),
#  layers.Dropout(0.2),
#  layers.Flatten(),
#  layers.Dense(128, activation='relu'),
#  layers.Dense(target_labels)
#])
model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(target_labels, activation='softmax')
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_2 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 180, 180, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 90, 90, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 45, 45, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 45, 45, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 61952)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │      15,859,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,956,425 (60.87 MB)
#  Trainable params: 15,955,977 (60.87 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# #### **Todo:**  Train your model

# %%
# %%time
epochs = 30
## Your code goes here, use 30 epochs.
history = model.fit(
  train_ds2,
  validation_data=val_ds2,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - accuracy: 0.2120 - loss: 9.5101 - val_accuracy: 0.1084 - val_loss: 42.3488
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 20s 116ms/step - accuracy: 0.1761 - loss: 2.1361 - val_accuracy: 0.1114 - val_loss: 19.4733
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.1767 - loss: 2.1003 - val_accuracy: 0.2168 - val_loss: 2.1959
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.1885 - loss: 2.1008 - val_accuracy: 0.2331 - val_loss: 2.1507
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.1822 - loss: 2.0774 - val_accuracy: 0.1685 - val_loss: 3.3122
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - accuracy: 0.1907 - loss: 2.0547 - val_accuracy: 0.2227 - val_loss: 2.2832
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1968 - loss: 2.0542 - val_accuracy: 0.2524 - val_loss: 1.9197
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.1888 - loss: 2.0623 - val_accuracy: 0.1915 - val_loss: 2.8038
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1894 - loss: 2.0618 - val_accuracy: 0.1759 - val_loss: 2.2076
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.1972 - loss: 2.0356 - val_accuracy: 0.2183 - val_loss: 2.0413
# Epoch 11/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1850 - loss: 2.0317 - val_accuracy: 0.2056 - val_loss: 2.0406
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.1960 - loss: 2.0402 - val_accuracy: 0.1670 - val_loss: 2.1183
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1803 - loss: 2.0540 - val_accuracy: 0.2264 - val_loss: 1.9154
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1910 - loss: 2.0382 - val_accuracy: 0.2398 - val_loss: 1.9063
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1863 - loss: 2.0415 - val_accuracy: 0.2079 - val_loss: 2.0409
# Epoch 16/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1870 - loss: 2.0437 - val_accuracy: 0.2435 - val_loss: 1.8797
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1939 - loss: 2.0278 - val_accuracy: 0.1774 - val_loss: 2.3789
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 111ms/step - accuracy: 0.1928 - loss: 2.0365 - val_accuracy: 0.1849 - val_loss: 2.2176
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1955 - loss: 2.0326 - val_accuracy: 0.2368 - val_loss: 1.8786
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1988 - loss: 2.0159 - val_accuracy: 0.2108 - val_loss: 1.9735
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1893 - loss: 2.0335 - val_accuracy: 0.2279 - val_loss: 1.9799
# Epoch 22/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1936 - loss: 2.0226 - val_accuracy: 0.2227 - val_loss: 2.1219
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1835 - loss: 2.0512 - val_accuracy: 0.2131 - val_loss: 1.9885
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1934 - loss: 2.0441 - val_accuracy: 0.2398 - val_loss: 1.9504
# Epoch 25/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - accuracy: 0.2011 - loss: 2.0138 - val_accuracy: 0.1670 - val_loss: 2.8887
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 111ms/step - accuracy: 0.1749 - loss: 2.0890 - val_accuracy: 0.0713 - val_loss: 8.1169
# Epoch 27/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1941 - loss: 2.0366 - val_accuracy: 0.1804 - val_loss: 2.1334
# Epoch 28/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1848 - loss: 2.0285 - val_accuracy: 0.2235 - val_loss: 1.9596
# Epoch 29/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 113ms/step - accuracy: 0.1918 - loss: 2.0190 - val_accuracy: 0.2442 - val_loss: 1.8982
# Epoch 30/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - accuracy: 0.1754 - loss: 2.0498 - val_accuracy: 0.2398 - val_loss: 1.8836
# CPU times: user 24min 3s, sys: 49.8 s, total: 24min 53s
# Wall time: 9min 39s

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ### Observations:
#
# 1. Implementing batch normalization and augmentation lead to reduction in both training and validation accuracy.
# 2. Training and validation accuracies are in similar range.
# 3. This indicates underfitting.
# 4. Trying to remove batch normalization.

# %%
## your code goes here
model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(target_labels, activation='softmax')
])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# ModelCheckpoint callback is employed alongside the model.fit() training process to periodically save the model
# or its weights (in a checkpoint file)
checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

# Early stop the training when a monitored metric ceases to show improvement
earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# Training the model

# %%
# %%time
# train the model
epochs = 50
history = model.fit(
  train_ds2,
  validation_data=val_ds2,
  epochs=epochs,
  callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1441 - loss: 2.4937
# Epoch 1: val_accuracy improved from -inf to 0.25241, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.1447 - loss: 2.4898 - val_accuracy: 0.2524 - val_loss: 2.0962
# Epoch 2/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.3367 - loss: 1.7064
# Epoch 2: val_accuracy improved from 0.25241 to 0.43504, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.3370 - loss: 1.7058 - val_accuracy: 0.4350 - val_loss: 1.4919
# Epoch 3/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4261 - loss: 1.5114
# Epoch 3: val_accuracy improved from 0.43504 to 0.45657, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.4262 - loss: 1.5113 - val_accuracy: 0.4566 - val_loss: 1.4362
# Epoch 4/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4461 - loss: 1.4583
# Epoch 4: val_accuracy improved from 0.45657 to 0.46919, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - accuracy: 0.4461 - loss: 1.4582 - val_accuracy: 0.4692 - val_loss: 1.4154
# Epoch 5/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4428 - loss: 1.4490
# Epoch 5: val_accuracy improved from 0.46919 to 0.51745, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.4429 - loss: 1.4488 - val_accuracy: 0.5174 - val_loss: 1.2921
# Epoch 6/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4709 - loss: 1.3591
# Epoch 6: val_accuracy did not improve from 0.51745
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - accuracy: 0.4709 - loss: 1.3592 - val_accuracy: 0.5160 - val_loss: 1.2659
# Epoch 7/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4711 - loss: 1.3547
# Epoch 7: val_accuracy did not improve from 0.51745
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.4711 - loss: 1.3548 - val_accuracy: 0.5145 - val_loss: 1.2707
# Epoch 8/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4883 - loss: 1.3281
# Epoch 8: val_accuracy improved from 0.51745 to 0.54566, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.4884 - loss: 1.3280 - val_accuracy: 0.5457 - val_loss: 1.2159
# Epoch 9/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5078 - loss: 1.2537
# Epoch 9: val_accuracy did not improve from 0.54566
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.5076 - loss: 1.2541 - val_accuracy: 0.5004 - val_loss: 1.3500
# Epoch 10/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5132 - loss: 1.2538
# Epoch 10: val_accuracy improved from 0.54566 to 0.55382, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.5132 - loss: 1.2538 - val_accuracy: 0.5538 - val_loss: 1.1702
# Epoch 11/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5069 - loss: 1.2590
# Epoch 11: val_accuracy improved from 0.55382 to 0.57090, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - accuracy: 0.5070 - loss: 1.2589 - val_accuracy: 0.5709 - val_loss: 1.1257
# Epoch 12/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5494 - loss: 1.1750
# Epoch 12: val_accuracy did not improve from 0.57090
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.5493 - loss: 1.1752 - val_accuracy: 0.5464 - val_loss: 1.1610
# Epoch 13/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5410 - loss: 1.1926
# Epoch 13: val_accuracy did not improve from 0.57090
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.5409 - loss: 1.1927 - val_accuracy: 0.5509 - val_loss: 1.1034
# Epoch 14/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5551 - loss: 1.1423
# Epoch 14: val_accuracy improved from 0.57090 to 0.59762, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.5550 - loss: 1.1424 - val_accuracy: 0.5976 - val_loss: 1.0508
# Epoch 15/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5703 - loss: 1.1046
# Epoch 15: val_accuracy did not improve from 0.59762
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.5702 - loss: 1.1048 - val_accuracy: 0.5776 - val_loss: 1.0912
# Epoch 16/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5851 - loss: 1.0834
# Epoch 16: val_accuracy did not improve from 0.59762
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.5850 - loss: 1.0838 - val_accuracy: 0.5716 - val_loss: 1.1519
# Epoch 17/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5741 - loss: 1.0951
# Epoch 17: val_accuracy did not improve from 0.59762
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.5743 - loss: 1.0948 - val_accuracy: 0.5939 - val_loss: 1.0756
# Epoch 18/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6074 - loss: 1.0186
# Epoch 18: val_accuracy improved from 0.59762 to 0.62287, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.6072 - loss: 1.0191 - val_accuracy: 0.6229 - val_loss: 0.9855
# Epoch 19/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6026 - loss: 1.0081
# Epoch 19: val_accuracy did not improve from 0.62287
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.6026 - loss: 1.0083 - val_accuracy: 0.6058 - val_loss: 1.0084
# Epoch 20/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6015 - loss: 1.0024
# Epoch 20: val_accuracy improved from 0.62287 to 0.63252, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.6016 - loss: 1.0026 - val_accuracy: 0.6325 - val_loss: 0.9601
# Epoch 21/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6268 - loss: 0.9779
# Epoch 21: val_accuracy did not improve from 0.63252
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.6267 - loss: 0.9780 - val_accuracy: 0.6221 - val_loss: 1.0165
# Epoch 22/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6226 - loss: 0.9618
# Epoch 22: val_accuracy improved from 0.63252 to 0.66295, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.6226 - loss: 0.9617 - val_accuracy: 0.6630 - val_loss: 0.9131
# Epoch 23/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6490 - loss: 0.9332
# Epoch 23: val_accuracy did not improve from 0.66295
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.6489 - loss: 0.9335 - val_accuracy: 0.6340 - val_loss: 0.9443
# Epoch 24/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6509 - loss: 0.9282
# Epoch 24: val_accuracy did not improve from 0.66295
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.6509 - loss: 0.9281 - val_accuracy: 0.6414 - val_loss: 0.9941
# Epoch 25/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6647 - loss: 0.8864
# Epoch 25: val_accuracy did not improve from 0.66295
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.6646 - loss: 0.8865 - val_accuracy: 0.6310 - val_loss: 1.0845
# Epoch 26/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6541 - loss: 0.8725
# Epoch 26: val_accuracy improved from 0.66295 to 0.68448, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.6543 - loss: 0.8724 - val_accuracy: 0.6845 - val_loss: 0.9319
# Epoch 27/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6840 - loss: 0.8386
# Epoch 27: val_accuracy improved from 0.68448 to 0.70007, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.6838 - loss: 0.8389 - val_accuracy: 0.7001 - val_loss: 0.8040
# Epoch 28/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6795 - loss: 0.8386
# Epoch 28: val_accuracy did not improve from 0.70007
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - accuracy: 0.6795 - loss: 0.8386 - val_accuracy: 0.6808 - val_loss: 0.8419
# Epoch 29/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6841 - loss: 0.8118
# Epoch 29: val_accuracy did not improve from 0.70007
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.6842 - loss: 0.8119 - val_accuracy: 0.6875 - val_loss: 0.8224
# Epoch 30/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6916 - loss: 0.8161
# Epoch 30: val_accuracy improved from 0.70007 to 0.72532, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.6915 - loss: 0.8162 - val_accuracy: 0.7253 - val_loss: 0.7551
# Epoch 31/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7057 - loss: 0.7745
# Epoch 31: val_accuracy improved from 0.72532 to 0.73348, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - accuracy: 0.7057 - loss: 0.7746 - val_accuracy: 0.7335 - val_loss: 0.7810
# Epoch 32/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7140 - loss: 0.7698
# Epoch 32: val_accuracy did not improve from 0.73348
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.7140 - loss: 0.7698 - val_accuracy: 0.7268 - val_loss: 0.7550
# Epoch 33/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7146 - loss: 0.7447
# Epoch 33: val_accuracy improved from 0.73348 to 0.73794, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.7146 - loss: 0.7448 - val_accuracy: 0.7379 - val_loss: 0.7100
# Epoch 34/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7017 - loss: 0.7666
# Epoch 34: val_accuracy did not improve from 0.73794
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.7017 - loss: 0.7665 - val_accuracy: 0.7313 - val_loss: 0.7214
# Epoch 35/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7258 - loss: 0.7083
# Epoch 35: val_accuracy improved from 0.73794 to 0.76689, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.7258 - loss: 0.7083 - val_accuracy: 0.7669 - val_loss: 0.7142
# Epoch 36/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7333 - loss: 0.7051
# Epoch 36: val_accuracy did not improve from 0.76689
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.7331 - loss: 0.7054 - val_accuracy: 0.6748 - val_loss: 0.9297
# Epoch 37/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7249 - loss: 0.7293
# Epoch 37: val_accuracy did not improve from 0.76689
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.7247 - loss: 0.7299 - val_accuracy: 0.6964 - val_loss: 0.8269
# Epoch 38/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7119 - loss: 0.7403
# Epoch 38: val_accuracy did not improve from 0.76689
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.7121 - loss: 0.7400 - val_accuracy: 0.7610 - val_loss: 0.6822
# Epoch 39/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7448 - loss: 0.6854
# Epoch 39: val_accuracy did not improve from 0.76689
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.7447 - loss: 0.6858 - val_accuracy: 0.7461 - val_loss: 0.6927
# Epoch 40/50
# 168/169 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7308 - loss: 0.6876
# Epoch 40: val_accuracy did not improve from 0.76689
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.7309 - loss: 0.6876 - val_accuracy: 0.7283 - val_loss: 0.7271
# Epoch 40: early stopping
# CPU times: user 29min, sys: 1min 15s, total: 30min 16s
# Wall time: 9min 54s

# %% [markdown]
# Visualize the model results

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_3 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 45, 45, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 22, 22, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 61952)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │      15,859,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 47,866,589 (182.60 MB)
#  Trainable params: 15,955,529 (60.87 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 31,911,060 (121.73 MB)

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #### Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# #### Observations:
#
# 1. The final model showcases well-balanced performance, displaying no signs of underfitting or overfitting.
#
# 2. The implementation of class rebalancing has notably enhanced the model's performance across both training and validation datasets.
#
# 3. Following 40 epochs, the final model attains an accuracy of 73% on the training set and approximately 72% on the validation set.
#
# 4. The narrow divergence between training and validation accuracies underscores the robust generalization capability of the final CNN model.
#
# 5. The addition of batch normalization failed to enhance both training and validation accuracy.

# %% [markdown]
# #### Final Model Evaluation

# %%
# Evaluating our model on one instance of all classes in the test set

from tensorflow.keras.preprocessing.image import load_img

for i in range(0,8):
  image_path_test = os.path.join(data_dir_test, class_names[i], '*')
  test_image = glob(image_path_test)
  test_image = load_img(test_image[-1], target_size=(180, 180, 3))
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(test_image)
  plt.grid(False)
  img = np.expand_dims(test_image, axis=0)
  predicted = model.predict(img)
  predicted = np.argmax(predicted)
  predicted_class = class_names[predicted]
  print("Actual Class: " + class_names[i] +'\n'+ "Predicted Class: " + predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Actual Class: actinic keratosis
# Predicted Class: pigmented benign keratosis
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: basal cell carcinoma
# Predicted Class: basal cell carcinoma
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: dermatofibroma
# Predicted Class: dermatofibroma
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: melanoma
# Predicted Class: nevus
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: nevus
# Predicted Class: nevus
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: pigmented benign keratosis
# Predicted Class: basal cell carcinoma
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: seborrheic keratosis
# Predicted Class: dermatofibroma
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: squamous cell carcinoma
# Predicted Class: squamous cell carcinoma
